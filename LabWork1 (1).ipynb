# %% [markdown]
# # Лабораторная работа 1
# ## Исследование набора данных ирисы Фишера

# %% [markdown]
# ### Подключение библиотеки NumPy и загрузка данных

# %%
import numpy as np
data_path = "/content/auto-mpg (1).data-original"
data = np.genfromtxt(data_path, delimiter=",")
print(data)
# Out:
# [[ 18.   8. 307. ...  70.   1.  nan]
#  [ 15.   8. 350. ...  70.   1.  nan]
#  [ 18.   8. 318. ...  70.   1.  nan]
#  ...
#  [ 32.   4. 135. ...  82.   1.  nan]
#  [ 28.   4. 120. ...  82.   1.  nan]
#  [ 31.   4. 119. ...  82.   1.  nan]]

# %% [markdown]
# ### Тип переменной и форма (shape)

# %%
print ( "Data type : ", type(data) )
print ( "Data shape : ", data.shape )
print ( data[-4:] )
# Out:
# Data type :  <class 'numpy.ndarray'>
# Data shape :  (406, 9)
# [[4.400e+01 4.000e+00 9.700e+01 5.200e+01 2.130e+03 2.460e+01 8.200e+01
#   2.000e+00       nan]
#  [3.200e+01 4.000e+00 1.350e+02 8.400e+01 2.295e+03 1.160e+01 8.200e+01
#   1.000e+00       nan]
#  [2.800e+01 4.000e+00 1.200e+02 7.900e+01 2.625e+03 1.860e+01 8.200e+01
#   1.000e+00       nan]
#  [3.100e+01 4.000e+00 1.190e+02 8.200e+01 2.720e+03 1.940e+01 8.200e+01
#   1.000e+00       nan]]

# %% [markdown]
# ### Получение типа набора данных, строки, элемента

# %%
data1 = np.genfromtxt(data_path, delimiter=",", dtype=None)
print('Shape of the dataset:', data1.shape)
print('Dataset type:', type(data1))
print('A single row of the dataset is type of:', type(data1[0]))
print('Types of elements:', type(data1[0][1]), type(data1[0][4]))
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (406,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.float64'>
# Dataset:
# [(b'18.0', 8., 307. , b'130.0', 3504., 12. , 70., 1., b'"chevrolet chevelle malibu"')
#  (b'15.0', 8., 350. , b'165.0', 3693., 11.5, 70., 1., b'"buick skylark 320"')
#  (b'18.0', 8., 318. , b'150.0', 3436., 11. , 70., 1., b'"plymouth satellite"')
#  (b'16.0', 8., 304. , b'150.0', 3433., 12. , 70., 1., b'"amc rebel sst"')
#  (b'17.0', 8., 302. , b'140.0', 3449., 10.5, 70., 1., b'"ford torino"')
#  (b'15.0', 8., 429. , b'198.0', 4341., 10. , 70., 1., b'"ford galaxie 500"')
#  (b'14.0', 8., 454. , b'220.0', 4354.,  9. , 70., 1., b'"chevrolet impala"')
#  (b'14.0', 8., 440. , b'215.0', 4312.,  8.5, 70., 1., b'"plymouth fury iii"')
#  (b'14.0', 8., 455. , b'225.0', 4425., 10. , 70., 1., b'"pontiac catalina"')
# ...

# %% [markdown]
# ### Указание типа столбцов при загрузке данных

# %%
dt = np.dtype("f8, f8, f8, f8, f8, f8, f8, f8, U30")
data2 = np.genfromtxt(data_path, delimiter=",", dtype=dt)
print('Shape of the dataset:', data2.shape)
print('Dataset type:', type(data2))
print('A single row of the dataset is type of:', type(data2[0]))
print('Types of elements:', type(data2[0][1]), type(data2[0][4]))
print('Dataset slice:')
print(data2[:10])
# Out:
# Shape of the dataset: (406,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.float64'>
# Dataset slice:
# [(18., 8., 307., 130., 3504., 12. , 70., 1., '"chevrolet chevelle malibu"')
#  (15., 8., 350., 165., 3693., 11.5, 70., 1., '"buick skylark 320"')
#  (18., 8., 318., 150., 3436., 11. , 70., 1., '"plymouth satellite"')
#  (16., 8., 304., 150., 3433., 12. , 70., 1., '"amc rebel sst"')
#  (17., 8., 302., 140., 3449., 10.5, 70., 1., '"ford torino"')
#  (15., 8., 429., 198., 4341., 10. , 70., 1., '"ford galaxie 500"')
#  (14., 8., 454., 220., 4354.,  9. , 70., 1., '"chevrolet impala"')
#  (14., 8., 440., 215., 4312.,  8.5, 70., 1., '"plymouth fury iii"')
#  (14., 8., 455., 225., 4425., 10. , 70., 1., '"pontiac catalina"')
#  (15., 8., 390., 190., 3850.,  8.5, 70., 1., '"amc ambassador dpl"')]

# %% [markdown]
# ### Построение графиков с использованием Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Данные из отдельных столбцов
displacement = []
mpg = []
cylinders = []
horsepower = []
weight = []
acceleration = []
model_year = []
origin = []

# Выполняем обход всей коллекции data2
for dot in data:
  displacement.append(dot[0])
  mpg.append(dot[1])
  cylinders.append(dot[2])
  horsepower.append(dot[3])
  weight.append(dot[4])
  acceleration.append(dot[5])
  model_year.append(dot[6])
  origin.append(dot[7])

# Строим графики по проекциям данных
# Учитываем, что каждые 50 типов ирисов идут последовательно
plt.figure(1)
mpg_displacement = plt.plot(displacement[:100], mpg[:100], 'ro', label='mpg_displacement')
mpg_displacement = plt.plot(displacement[100:200], mpg[100:200], 'g^', label='mpg_displacement')
mpg_displacement = plt.plot(displacement[200:300], mpg[200:300], 'bs', label='mpg_displacement')
mpg_displacement = plt.plot(displacement[300:398], mpg[300:398], 'go', label='mpg_displacement')
plt.xlabel("Displacement")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.figure(2)
mpg_cylinders = plt.plot(cylinders[:100], mpg[:100], 'ro', label='mpg_cylinders')
mpg_cylinders = plt.plot(cylinders[100:200], mpg[100:200], 'g^', label='mpg_cylinders')
mpg_cylinders = plt.plot(cylinders[200:300], mpg[200:300], 'bs', label='mpg_cylinders')
mpg_cylinders = plt.plot(cylinders[300:398], mpg[300:398], 'go', label='mpg_cylinders')

plt.xlabel("Cylinders")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.figure(3)
mpg_horsepower = plt.plot(horsepower[:100], mpg[:100], 'ro', label='mpg_horsepower')
mpg_horsepower = plt.plot(horsepower[100:200], mpg[100:200], 'g^', label='mpg_horsepower')
mpg_horsepower = plt.plot(horsepower[200:300], mpg[200:300], 'bs', label='mpg_horsepower')
mpg_horsepower = plt.plot(horsepower[300:398], mpg[300:398], 'go', label='mpg_horsepower')

plt.xlabel("Horsepower")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.figure(4)
mpg_weight = plt.plot(weight[:100], mpg[:100], 'ro', label='mpg_weight')
mpg_weight = plt.plot(weight[100:200], mpg[100:200], 'g^', label='mpg_weight')
mpg_weight = plt.plot(weight[200:300], mpg[200:300], 'bs', label='mpg_weight')
mpg_weight = plt.plot(weight[300:398], mpg[300:398], 'go', label='mpg_weight')

plt.xlabel("Weight")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.figure(5)
mpg_acceleration = plt.plot(acceleration[:100], mpg[:100], 'ro', label='mpg_acceleration')
mpg_acceleration = plt.plot(acceleration[100:200], mpg[100:200], 'g^', label='mpg_acceleration')
mpg_acceleration = plt.plot(acceleration[200:300], mpg[200:300], 'bs', label='mpg_acceleration')
mpg_acceleration = plt.plot(acceleration[300:398], mpg[300:398], 'go', label='mpg_acceleration')

plt.xlabel("Acceleration")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.figure(6)
mpg_model_year = plt.plot(model_year[:100], mpg[:100], 'ro', label='mpg_model_year')
mpg_model_year = plt.plot(model_year[100:200], mpg[100:200], 'g^', label='mpg_model_year')
mpg_model_year = plt.plot(model_year[200:300], mpg[200:300], 'bs', label='mpg_model_year')
mpg_model_year = plt.plot(model_year[300:398], mpg[300:398], 'go', label='mpg_model_year')

plt.xlabel("Model year")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.figure(7)
mpg_origin = plt.plot(origin[:100], mpg[:100], 'ro', label='mpg_origin')
mpg_origin = plt.plot(origin[100:200], mpg[100:200], 'g^', label='mpg_origin')
mpg_origin = plt.plot(origin[200:300], mpg[200:300], 'bs', label='mpg_origin')
mpg_origin = plt.plot(origin[300:398], mpg[300:398], 'go', label='mpg_origin')

plt.xlabel("Origin")
plt.ylabel('Mpg')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
